# %%
import pandas as pd

import os
import glob

# %%
def load_dfs(filename: str):
    all_csv = glob.glob(f'{os.getcwd()}/data/*/{filename}.csv')
    return pd.concat((pd.read_csv(filename, index_col='temp_id') for filename in all_csv), axis=0)

# %%
# Drop duplicate indices
def clean_indices(df):
    no_dups_df = df.loc[~df.index.duplicated(keep='first')]
    return no_dups_df

# %%
# Merge poeple and address
# Get address to people relations
def load_mapping(filename: str):
    all_csv = glob.glob(f'{os.getcwd()}/data/*/{filename}.csv')
    return pd.concat((pd.read_csv(filename) for filename in all_csv), axis=0)
mappings = load_mapping('ADDRESSES_PEOPLE')

# %%
df = load_dfs('PEOPLE')

# %%
df = clean_indices(df)

# %%
df = mappings.merge(df, left_on='person_uuid', right_index=True)

# %%
# Join addresses
address_df = load_dfs('ADDRESSES')

# %%
address_df = clean_indices(address_df)
address_df.index = address_df.index.rename('id')

# %%
address_df
# Out:
#                                                 address  lat  lon  \
# id
# 2                            rikshospitaletoslo, norway  NaN  NaN
# 3                        university of oslooslo, norway  NaN  NaN
# 4     uit the arctic university of norwaytromsø, norway  NaN  NaN
# 5                            rikshospitaletoslo, norway  NaN  NaN
# 6                            rikshospitaletoslo, norway  NaN  NaN
# ...                                                 ...  ...  ...
# 1496      p.o. box  blindern, 1068, n-0316 oslo, norway  NaN  NaN
# 1497      p.o. box  blindern, 1068, n-0316 oslo, norway  NaN  NaN
# 1498      p.o. box  blindern, 1068, n-0316 oslo, norway  NaN  NaN
# 1499      p.o. box  blindern, 1068, n-0316 oslo, norway  NaN  NaN
# 1500                  p.o. box, 5003, n-1432 as, norway  NaN  NaN
#
#                                                    name  phone  address_url
# id
# 2     section of nephrology, department of transplan...    NaN          NaN
# 3     faculty of medicine, institute of clinical med...    NaN          NaN
# 4                    metabolic and renal research group    NaN          NaN
# 5     section of specialized endocrinology, departme...    NaN          NaN
# 6     section of nephrology, department of transplan...    NaN          NaN
# ...                                                 ...    ...          ...
# 1496  department of pharmaceutical chemistry, sectio...    NaN          NaN
# 1497  department of pharmaceutical chemistry, sectio...    NaN          NaN
# 1498  department of pharmaceutical chemistry, sectio...    NaN          NaN
# 1499  department of pharmaceutical chemistry, sectio...    NaN          NaN
# 1500  department of chemistry, biotechnology and foo...    NaN          NaN
#
# [1499 rows x 6 columns]

# %%
# duplicated column
address_df = address_df.drop(columns=['countries_scope'])
address_df= address_df.rename(columns={'url': 'address_url'})

# %%
df = df.merge(address_df, left_on='address_uuid', right_index=True)
df = df.set_index('person_uuid', drop=True)
df = clean_indices(df)
df = df.drop(columns=['address_uuid'])

# %%
# Remove duplicated indices because on next merge kernel is going to die a lot
df = clean_indices(df)

# %%
publications_df = load_dfs('PUBLICATIONS')
publications_df = clean_indices(publications_df)
publications_df = publications_df.rename(columns={'url': 'publication_url'})

# %%
people_publications_mapping = load_mapping('PEOPLE_PUBLICATIONS')

# %%
df = df.merge(people_publications_mapping, left_index=True, right_on='person_uuid')

# %%
df = df.merge(publications_df, left_on='publication_uuid', right_index=True).set_index('person_uuid')

# %%
df = clean_indices(df)
df
# Out:
#                lastname        firstname countries_scope  \
# person_uuid
# 1            von Düring  Marit Elizabeth              NO
# 2               Jenssen            Trond              NO
# 3            Bollerslev             Jens              NO
# 4                Godang          Kristin              NO
# 5              Hartmann           Anders              NO
# ...                 ...              ...             ...
# 1495             Rusten           Anders              NO
# 1496              Bugge    Mona Skogsrud              NO
# 1497           Malterud        Karl Egil              NO
# 1498            Paulsen    Berit Smestad              NO
# 1499              Brede       Dag Anders              NO
#
#                                     email         town  role  url  \
# person_uuid
# 1                                     NaN         oslo   NaN  NaN
# 2                                     NaN         oslo   NaN  NaN
# 3                                     NaN         oslo   NaN  NaN
# 4                                     NaN         oslo   NaN  NaN
# 5                                     NaN         oslo   NaN  NaN
# ...                                   ...          ...   ...  ...
# 1495                                  NaN  n-0316 oslo   NaN  NaN
# 1496                                  NaN  n-0316 oslo   NaN  NaN
# 1497                                  NaN  n-0316 oslo   NaN  NaN
# 1498                                  NaN  n-0316 oslo   NaN  NaN
# 1499         dag.anders.brede@ikbm.nlh.no    n-1432 as   NaN  NaN
#
#                                                        address  lat  lon  \
# person_uuid
# 1                                   rikshospitaletoslo, norway  NaN  NaN
# 2                               university of oslooslo, norway  NaN  NaN
# 3            uit the arctic university of norwaytromsø, norway  NaN  NaN
# 4                                   rikshospitaletoslo, norway  NaN  NaN
# 5                                   rikshospitaletoslo, norway  NaN  NaN
# ...                                                        ...  ...  ...
# 1495             p.o. box  blindern, 1068, n-0316 oslo, norway  NaN  NaN
# 1496             p.o. box  blindern, 1068, n-0316 oslo, norway  NaN  NaN
# 1497             p.o. box  blindern, 1068, n-0316 oslo, norway  NaN  NaN
# 1498             p.o. box  blindern, 1068, n-0316 oslo, norway  NaN  NaN
# 1499                         p.o. box, 5003, n-1432 as, norway  NaN  NaN
#
#                                                           name  phone  \
# person_uuid
# 1            section of nephrology, department of transplan...    NaN
# 2            faculty of medicine, institute of clinical med...    NaN
# 3                           metabolic and renal research group    NaN
# 4            section of specialized endocrinology, departme...    NaN
# 5            section of nephrology, department of transplan...    NaN
# ...                                                        ...    ...
# 1495         department of pharmaceutical chemistry, sectio...    NaN
# 1496         department of pharmaceutical chemistry, sectio...    NaN
# 1497         department of pharmaceutical chemistry, sectio...    NaN
# 1498         department of pharmaceutical chemistry, sectio...    NaN
# 1499         department of chemistry, biotechnology and foo...    NaN
#
#              address_url  publication_uuid  \
# person_uuid
# 1                    NaN                 1
# 2                    NaN                 1
# 3                    NaN                 1
# 4                    NaN                 1
# 5                    NaN                 1
# ...                  ...               ...
# 1495                 NaN               807
# 1496                 NaN               807
# 1497                 NaN               807
# 1498                 NaN               807
# 1499                 NaN               808
#
#                                                          title  pubmed_id  \
# person_uuid
# 1            Arterial stiffness is associated with visceral...   29957825
# 2            Arterial stiffness is associated with visceral...   29957825
# 3            Arterial stiffness is associated with visceral...   29957825
# 4            Arterial stiffness is associated with visceral...   29957825
# 5            Arterial stiffness is associated with visceral...   29957825
# ...                                                        ...        ...
# 1495         Flavonoids, gallotannins and ellagitannins in ...   27647014
# 1496         Flavonoids, gallotannins and ellagitannins in ...   27647014
# 1497         Flavonoids, gallotannins and ellagitannins in ...   27647014
# 1498         Flavonoids, gallotannins and ellagitannins in ...   27647014
# 1499         Molecular and genetic characterization of prop...   15574930
#
#                                                        journal    year  \
# person_uuid
# 1            Clinical transplantation. Volume: 32 Issue: 8 ...  2018.0
# 2            Clinical transplantation. Volume: 32 Issue: 8 ...  2018.0
# 3            Clinical transplantation. Volume: 32 Issue: 8 ...  2018.0
# 4            Clinical transplantation. Volume: 32 Issue: 8 ...  2018.0
# 5            Clinical transplantation. Volume: 32 Issue: 8 ...  2018.0
# ...                                                        ...     ...
# 1495         Journal of ethnopharmacology. Volume: 192 Nov ...  2016.0
# 1496         Journal of ethnopharmacology. Volume: 192 Nov ...  2016.0
# 1497         Journal of ethnopharmacology. Volume: 192 Nov ...  2016.0
# 1498         Journal of ethnopharmacology. Volume: 192 Nov ...  2016.0
# 1499         Applied and environmental microbiology. Volume...  2004.0
#
#                                           publication_url  \
# person_uuid
# 1            http://www.ncbi.nlm.nih.gov/pubmed/29957825/
# 2            http://www.ncbi.nlm.nih.gov/pubmed/29957825/
# 3            http://www.ncbi.nlm.nih.gov/pubmed/29957825/
# 4            http://www.ncbi.nlm.nih.gov/pubmed/29957825/
# 5            http://www.ncbi.nlm.nih.gov/pubmed/29957825/
# ...                                                   ...
# 1495         http://www.ncbi.nlm.nih.gov/pubmed/27647014/
# 1496         http://www.ncbi.nlm.nih.gov/pubmed/27647014/
# 1497         http://www.ncbi.nlm.nih.gov/pubmed/27647014/
# 1498         http://www.ncbi.nlm.nih.gov/pubmed/27647014/
# 1499         http://www.ncbi.nlm.nih.gov/pubmed/15574930/
#
#                                                       abstract
# person_uuid
# 1            Arterial stiffness, visceral fat, and hypergly...
# 2            Arterial stiffness, visceral fat, and hypergly...
# 3            Arterial stiffness, visceral fat, and hypergly...
# 4            Arterial stiffness, visceral fat, and hypergly...
# 5            Arterial stiffness, visceral fat, and hypergly...
# ...                                                        ...
# 1495         Syzygium guineense has been traditionally used...
# 1496         Syzygium guineense has been traditionally used...
# 1497         Syzygium guineense has been traditionally used...
# 1498         Syzygium guineense has been traditionally used...
# 1499         This work describes the purification and chara...
#
# [1499 rows x 20 columns]

# %%
# Save to csv
df.to_csv('merged.csv')

# %% [markdown]
# # Matplotlib

# %%
import numpy as np
town_publication_count = df.groupby('town')
town_publication_count = town_publication_count.filter(lambda x: x['publication_uuid'].count() > 10)
town_publication_count = town_publication_count.groupby('town').count()
town_publication_count



town_publication_count.plot.bar(y='publication_uuid')

# %%
df.lon.notnull()
# Out:
# person_uuid
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 1495    False
# 1496    False
# 1497    False
# 1498    False
# 1499    False
# Name: lon, Length: 1499, dtype: bool

# %%
# Scatter plot - data does not have any lon or lat values

# %%
# Histogram - there is no gender in the data unfortunately
year_publication_count = df.groupby('year')
year_publication_count = year_publication_count.filter(lambda x: x['publication_uuid'].count() > 10)
year_publication_count = year_publication_count.groupby('year').count()
year_publication_count.plot.bar(y='publication_uuid')
