# %%
import pandas as pd

import os
import glob

# %%
def merge_dir(dir_name: str):
    dir_path = f'{os.getcwd()}/data/{dir_name}/'
    
    people_df = pd.read_csv(dir_path + 'PEOPLE.csv', index_col='temp_id')
    people_df = people_df.rename(columns={'url': 'person_url'})
    
    address_people =  pd.read_csv(dir_path + 'ADDRESSES_PEOPLE.csv')
    
    df = address_people.merge(people_df, how='left', left_on='person_uuid', right_on='temp_id', right_index=True).set_index('person_uuid', drop=True)
    
    df['copy_index'] = df.index
    
    addresses_df = pd.read_csv(dir_path + 'ADDRESSES.csv', index_col='temp_id')
    addresses_df = addresses_df.drop(columns=['countries_scope'])
    addresses_df = addresses_df.rename(columns={'url': 'address_url'})
    
    df = df.merge(addresses_df, how='left', left_on='address_uuid', right_on='temp_id').set_index('copy_index')

    df['copy_index'] = df.index
    
    people_publications = pd.read_csv(dir_path + 'PEOPLE_PUBLICATIONS.csv')
    
    df = df.merge(people_publications, how='left', left_index=True, right_on='person_uuid')
    
    publications_df = pd.read_csv(dir_path + 'PUBLICATIONS.csv', index_col='temp_id')
    publications_df = publications_df.rename(columns={'url': 'publication_url'})
    
    df = df.merge(publications_df, left_on='publication_uuid', right_on='temp_id').reset_index()
    
    df = df.drop(['address_uuid', 'publication_uuid', 'person_uuid', 'copy_index'], axis=1)
    
    return df

# %%
df = merge_dir(0)
df
# Out:
#       index  lastname firstname countries_scope                         email  \
# 0         0  Andersen    Lars B              NO                           NaN
# 1         1  Knutsvik     Gøril              NO                           NaN
# 2         2  Knutsvik     Gøril              NO                           NaN
# 3         3  Knutsvik     Gøril              NO                           NaN
# 4         4   Collett     Karin              NO                           NaN
# ...     ...       ...       ...             ...                           ...
# 1991   1991      Nord         E              NO                           NaN
# 1992   1992     Jorde      Rolf              NO             rolf.jorde@unn.no
# 1993   1993   Engedal      Knut              NO                           NaN
# 1994   1994   Selbaek      Geir              NO                           NaN
# 1995   1995  Ulvestad         E              NO  elling.ulvestad@haukeland.no
#
#          town  role  person_url  \
# 0     sogndal   NaN         NaN
# 1      bergen   NaN         NaN
# 2      bergen   NaN         NaN
# 3      bergen   NaN         NaN
# 4      bergen   NaN         NaN
# ...       ...   ...         ...
# 1991     oslo   NaN         NaN
# 1992   tromsø   NaN         NaN
# 1993     oslo   NaN         NaN
# 1994     oslo   NaN         NaN
# 1995   bergen   NaN         NaN
#
#                                                 address  lat  lon  \
# 0     sogn og fjordane university collegesogndal, no...  NaN  NaN
# 1                    university of bergenbergen, norway  NaN  NaN
# 2           haukeland university hospitalbergen, norway  NaN  NaN
# 3           haukeland university hospitalbergen, norway  NaN  NaN
# 4           haukeland university hospitalbergen, norway  NaN  NaN
# ...                                                 ...  ...  ...
# 1991    national institute of public healthoslo, norway  NaN  NaN
# 1992                 university of tromsøtromsø, norway  NaN  NaN
# 1993               oslo university hospitaloslo, norway  NaN  NaN
# 1994               oslo university hospitaloslo, norway  NaN  NaN
# 1995        haukeland university hospitalbergen, norway  NaN  NaN
#
#                                                    name  phone  address_url  \
# 0                faculty of teacher education and sport    NaN          NaN
# 1     centre for cancer biomarkers, ccbio, departmen...    NaN          NaN
# 2                               department of pathology    NaN          NaN
# 3                               department of pathology    NaN          NaN
# 4                               department of pathology    NaN          NaN
# ...                                                 ...    ...          ...
# 1991                                                NaN    NaN          NaN
# 1992  department of internal medicine, institute of ...    NaN          NaN
# 1993                                                NaN    NaN          NaN
# 1994                                                NaN    NaN          NaN
# 1995  department of microbiology and immunology, the...    NaN          NaN
#
#                                                   title  pubmed_id  \
# 0     Cardiorespiratory fitness cut points to avoid ...   27670254
# 1     QSOX1 expression is associated with aggressive...   27562495
# 2     QSOX1 expression is associated with aggressive...   27562495
# 3     QSOX1 expression is associated with aggressive...   27562495
# 4     QSOX1 expression is associated with aggressive...   27562495
# ...                                                 ...        ...
# 1991  The trade-off between severity of illness and ...   10128127
# 1992  Neuropsychological function in relation to ser...   16283099
# 1993  Erratum to: Access to timely formal dementia c...   27793151
# 1994  Erratum to: Access to timely formal dementia c...   27793151
# 1995  Anti-cardiolipin autoantibodies and pulmonary ...   11093603
#
#                                                 journal    year  \
# 0     British journal of sports medicine. Volume: 50...  2016.0
# 1     Modern pathology : an official journal of the ...  2016.0
# 2     Modern pathology : an official journal of the ...  2016.0
# 3     Modern pathology : an official journal of the ...  2016.0
# 4     Modern pathology : an official journal of the ...  2016.0
# ...                                                 ...     ...
# 1991  Health policy (Amsterdam, Netherlands). Volume...  1993.0
# 1992  Journal of neurology. Volume: 253 Issue: 4 Apr...  2006.0
# 1993  BMC health services research. Volume: 16 Issue...  2016.0
# 1994  BMC health services research. Volume: 16 Issue...  2016.0
# 1995  Scandinavian journal of rheumatology. Volume: ...  2000.0
#
#                                    publication_url  \
# 0     http://www.ncbi.nlm.nih.gov/pubmed/27670254/
# 1     http://www.ncbi.nlm.nih.gov/pubmed/27562495/
# 2     http://www.ncbi.nlm.nih.gov/pubmed/27562495/
# 3     http://www.ncbi.nlm.nih.gov/pubmed/27562495/
# 4     http://www.ncbi.nlm.nih.gov/pubmed/27562495/
# ...                                            ...
# 1991  http://www.ncbi.nlm.nih.gov/pubmed/10128127/
# 1992  http://www.ncbi.nlm.nih.gov/pubmed/16283099/
# 1993  http://www.ncbi.nlm.nih.gov/pubmed/27793151/
# 1994  http://www.ncbi.nlm.nih.gov/pubmed/27793151/
# 1995  http://www.ncbi.nlm.nih.gov/pubmed/11093603/
#
#                                                abstract
# 0     Poor cardiorespiratory fitness is associated w...
# 1     The biological role of quiescin sulfhydryl oxi...
# 2     The biological role of quiescin sulfhydryl oxi...
# 3     The biological role of quiescin sulfhydryl oxi...
# 4     The biological role of quiescin sulfhydryl oxi...
# ...                                                 ...
# 1991  Social appreciation of health care programs is...
# 1992  There are receptors for parathyroid hormone (P...
# 1993                                                NaN
# 1994                                                NaN
# 1995  A patient with primary Sjögren's syndrome deve...
#
# [1996 rows x 20 columns]

# %%
df = pd.concat((merge_dir(i) for i in range(50)), axis=0, ignore_index=True)

# %%
df = df.drop_duplicates(['firstname', 'lastname', 'pubmed_id'])
df
# Out:
#        index   lastname        firstname countries_scope  \
# 0          0   Andersen           Lars B              NO
# 1          1   Knutsvik            Gøril              NO
# 4          4    Collett            Karin              NO
# 6          6      Arnes            Jarle              NO
# 9          9     Akslen           Lars A              NO
# ...      ...        ...              ...             ...
# 96541   1903    Omfjord      Christina S              NO
# 96542   1904      Rohde           Gudrun              NO
# 96543   1905    Kiserud                T              NO
# 96544   1906  Anderssen           Norman              NO
# 96545   1907     Hansen  Thor Willy Ruud              NO
#
#                                email                  town  role  person_url  \
# 0                                NaN               sogndal   NaN         NaN
# 1                                NaN                bergen   NaN         NaN
# 4                                NaN                bergen   NaN         NaN
# 6                                NaN                bergen   NaN         NaN
# 9                                NaN                bergen   NaN         NaN
# ...                              ...                   ...   ...         ...
# 96541         csandvand@hotmail.com.          kristiansand   NaN         NaN
# 96542         gudrun.e.rohde@uia.no.          kristiansand   NaN         NaN
# 96543       torvid.kiserud@kk.uib.no                bergen   NaN         NaN
# 96544  norman.anderssen@psych.uib.no  university of bergen   NaN         NaN
# 96545    t.w.r.hansen@medisin.uio.no                  oslo   NaN         NaN
#
#                                                  address  lat  lon  \
# 0      sogn og fjordane university collegesogndal, no...  NaN  NaN
# 1                     university of bergenbergen, norway  NaN  NaN
# 4            haukeland university hospitalbergen, norway  NaN  NaN
# 6                     university of bergenbergen, norway  NaN  NaN
# 9            haukeland university hospitalbergen, norway  NaN  NaN
# ...                                                  ...  ...  ...
# 96541            university of agderkristiansand, norway  NaN  NaN
# 96542            university of agderkristiansand, norway  NaN  NaN
# 96543        haukeland university hospitalbergen, norway  NaN  NaN
# 96544  department of psychosocial scienceuniversity o...  NaN  NaN
# 96545  oslo university hospital hc-rikshospitaletoslo...  NaN  NaN
#
#                                                     name  phone  address_url  \
# 0                 faculty of teacher education and sport    NaN          NaN
# 1      centre for cancer biomarkers, ccbio, departmen...    NaN          NaN
# 4                                department of pathology    NaN          NaN
# 6      centre for cancer biomarkers, ccbio, departmen...    NaN          NaN
# 9                                department of pathology    NaN          NaN
# ...                                                  ...    ...          ...
# 96541   department of public health, sport and nutrition    NaN          NaN
# 96542   department of public health, sport and nutrition    NaN          NaN
# 96543  department of clinical medicine, university of...    NaN          NaN
# 96544                                                NaN    NaN          NaN
# 96545  department of neonatology, women's and childre...    NaN          NaN
#
#                                                    title  pubmed_id  \
# 0      Cardiorespiratory fitness cut points to avoid ...   27670254
# 1      QSOX1 expression is associated with aggressive...   27562495
# 4      QSOX1 expression is associated with aggressive...   27562495
# 6      QSOX1 expression is associated with aggressive...   27562495
# 9      QSOX1 expression is associated with aggressive...   27562495
# ...                                                  ...        ...
# 96541  Physical education Teachers' and public health...   26704344
# 96542  Physical education Teachers' and public health...   26704344
# 96543  Global reproductive health: is diagnostic ultr...   22911621
# 96544  Outcomes for children with lesbian or gay pare...   12361102
# 96545  Advanced clinical medicine requires advanced c...   21791934
#
#                                                  journal    year  \
# 0      British journal of sports medicine. Volume: 50...  2016.0
# 1      Modern pathology : an official journal of the ...  2016.0
# 4      Modern pathology : an official journal of the ...  2016.0
# 6      Modern pathology : an official journal of the ...  2016.0
# 9      Modern pathology : an official journal of the ...  2016.0
# ...                                                  ...     ...
# 96541          BMC public health. Volume: 15 Dec 24 2015  2015.0
# 96542          BMC public health. Volume: 15 Dec 24 2015  2015.0
# 96543  Ultrasound in obstetrics & gynecology : the of...  2012.0
# 96544  Scandinavian journal of psychology. Volume: 43...  2002.0
# 96545             Neonatology. Volume: 101 Issue: 1 2012  2012.0
#
#                                     publication_url  \
# 0      http://www.ncbi.nlm.nih.gov/pubmed/27670254/
# 1      http://www.ncbi.nlm.nih.gov/pubmed/27562495/
# 4      http://www.ncbi.nlm.nih.gov/pubmed/27562495/
# 6      http://www.ncbi.nlm.nih.gov/pubmed/27562495/
# 9      http://www.ncbi.nlm.nih.gov/pubmed/27562495/
# ...                                             ...
# 96541  http://www.ncbi.nlm.nih.gov/pubmed/26704344/
# 96542  http://www.ncbi.nlm.nih.gov/pubmed/26704344/
# 96543  http://www.ncbi.nlm.nih.gov/pubmed/22911621/
# 96544  http://www.ncbi.nlm.nih.gov/pubmed/12361102/
# 96545  http://www.ncbi.nlm.nih.gov/pubmed/21791934/
#
#                                                 abstract
# 0      Poor cardiorespiratory fitness is associated w...
# 1      The biological role of quiescin sulfhydryl oxi...
# 4      The biological role of quiescin sulfhydryl oxi...
# 6      The biological role of quiescin sulfhydryl oxi...
# 9      The biological role of quiescin sulfhydryl oxi...
# ...                                                  ...
# 96541  High quality physical education programs in hi...
# 96542  High quality physical education programs in hi...
# 96543                                                NaN
# 96544  Twenty-three empirical studies published betwe...
# 96545  Many advances have occurred in clinical medici...
#
# [66292 rows x 20 columns]

# %%
# Save to csv
df.to_csv('merged.csv')

# %% [markdown]
# # Matplotlib

# %%
import numpy as np
town_publication_count = df.groupby('town')
town_publication_count = town_publication_count.filter(lambda x: x['pubmed_id'].count() > 150)
town_publication_count = town_publication_count.groupby('town').count()
town_publication_count



town_publication_count.plot.bar(y='pubmed_id')

# %%
df.lon.notnull()
# Out:
# 0        False
# 1        False
# 4        False
# 6        False
# 9        False
#          ...
# 96541    False
# 96542    False
# 96543    False
# 96544    False
# 96545    False
# Name: lon, Length: 66292, dtype: bool

# %%
# Scatter plot - data does not have any lon or lat values

# %%
# Histogram - there is no gender in the data unfortunately
year_publication_count = df.groupby('year')
year_publication_count = year_publication_count.filter(lambda x: x['pubmed_id'].count() > 10)
year_publication_count = year_publication_count.groupby('year').count()
year_publication_count.plot.bar(y='pubmed_id')
